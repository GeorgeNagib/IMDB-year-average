# %% [markdown]
# Importing Libiraries

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Getting movie data, group them by year and get the mean of the years of the list

# %%
movies = pd.read_csv('./IMDb_Data_final.csv')
movies = movies.sort_values('IMDb-Rating', ascending=False)

years_rate = movies.groupby(['ReleaseYear']).mean()
x = years_rate['IMDb-Rating'].index
y = years_rate['IMDb-Rating']

plt.plot(x,y)
